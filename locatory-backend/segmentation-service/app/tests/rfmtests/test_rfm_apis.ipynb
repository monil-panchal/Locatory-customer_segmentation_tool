# %%
import timeit
import requests

# %%
# Start-Stop service
data = '''{"client_name": "Al Seer", "action": "start"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }

    response = requests.post('http://localhost:8000/api/v1/start_stop_service', data=data, headers=header)
#     response = requests.post('http://209.97.130.29:8002/api/v1/start_stop_service', data=data, headers=header)
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# {u'message': u'Client: al_seer, is already using this service.'}

# %%
# Generate all
data = '''{"client_name": "al seer", "van_id": "VC12"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
    response = requests.post('http://localhost:8002/api/v1/generate_routes', data=data, headers=header)
    print timeit.default_timer() - start
#     response = requests.post('http://209.97.130.29:8002/api/v1/generate_routes', data=data, headers=header)
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 23.9896450043
# {u'message': u'Error while Generating RFM, Frequency, Route, Performance and Compliance Tables'}

# %%
# Route Plan Suggestion
data = '''{"client_name": "al seer", "van_id": "VC12", "goal": "hp"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }

#     response = requests.post('http://localhost:8000/api/v1/suggest_route', data=data, headers=header)
    response = requests.post('http://209.97.130.29:8002/api/v1/suggest_route', data=data, headers=header)
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# {u'message': u'Successfully fetched Route', u'year': u'2018', u'route': u'[{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"23735","Route_Date":1538352000000,"Day":1,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"30308","Route_Date":1538352000000,"Day":1,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"2170","Route_Date":1538352000000,"Day":1,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"2247","Route_Date":1538438400000,"Day":2,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"23579","Route_Date":1538438400000,"Day":2,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"2318","Route_Date":1538438400000,"Day":2,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Customer_ID":"24373","Route_Date":1538438400000,"Day":2,"Month":10},{"Year":2018,"SiteID":2100,"Goal":"hp","Van_ID":"VC12","Cu
# ...

# %%
# Evaluation
data = '''{"client_name": "gfc", "van_id": "VF05", "goal": "hp", "month": "05", "year": "2018"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }

#     response = requests.post('http://localhost:8000/api/v1/route_performance_reports', data=data, headers=header)
    response = requests.post('http://209.97.130.29:8002/api/v1/route_performance_reports', data=data, headers=header)
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-bff8f96becf0> in <module>()
#       9
#      10 #     response = requests.post('http://localhost:8000/api/v1/route_performance_reports', data=data, headers=header)
# ---> 11     response = requests.post('http://209.97.130.29:8002/api/v1/route_performance_reports', data=data, headers=header)
#      12 #     response = urlopen(request)
#      13     auth_code = response.json()
#
# /home/aamir/anaconda2/envs/rrapi/lib/python2.7/site-packages/requests/api.pyc in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# /home/aamir/anaconda2/envs/rrapi/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
# ...

# %%
# Test Customer Stats
# possible_cust_stats = ['most_frequent_buyers', 'best_custs', 'reliable_custs', 'highest_monetary_custs', 'stagnant_custs', 'non_productive_custs', 'poor_performing_custs']
# "max_results": 100
# van = ["VC03", "VB01"] [u'VJ55']
van = ["all"]

data = '''{"client_name": "al seer", "stat": "reliable_custs", "vans": "'''+str(van)+'''", "start_date": "2018-01-01", "end_date": "2018-06-30"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
    response = requests.post('http://localhost:8002/api/v1/get_customer_insights', data=data, headers=header)
#     response = requests.post('http://209.97.130.29:8002/api/v1/get_customer_insights', data=data, headers=header)
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 2.74606800079
# ...

# %%
# Test Product Stats
# possible_prod_stats = ['most_selling_prods', 'best_prods', 'reliable_prods', 'highest_monetary_prods', 'most_returned_prods', 'stagnant_prods', 'poor_performing_prods']
# "max_results": 100
org_ids = ['all']
agencies = ["all"]

data = '''{"client_name": "al seer", "stat": "poor_performing_prods", "org_ids": "'''+str(org_ids)+'''", 
        "agencies": "'''+str(agencies)+'''", "start_date": "2018-01-01", "end_date": "2018-06-30"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
    response = requests.post('http://localhost:8002/api/v1/get_product_insights', data=data, headers=header)
#     response = requests.post('http://209.97.130.29:8002/api/v1/get_product_insights', data=data, headers=header)
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 8.25461792946
# ...

# %%
# Test Dashboard Stats
    
data = '''{"client_name": "al seer", "dash_type": "gd"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
    response = requests.post('http://localhost:8002/api/v1/get_dash_insights', data=data, headers=header)
#     response = requests.post('http://209.97.130.29:8002/api/v1/get_dash_insights', data=data, headers=header)
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 1.25200986862
# ...

# %%
# Test Customers Data by Segments
    
data = '''{"client_name": "al seer", "drilldown_type": "rfm_customers", "segment": "A", "score_type": "R", "score": "5"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
#     response = requests.post('http://localhost:8000/api/v1/get_drilled_down_data', data=data, headers=header)
    response = requests.post('http://209.97.130.29:8002/api/v1/get_drilled_down_data', data=data, headers=header)
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 2.65214204788
# ...

# %%
# Test Products Data by Segments
    
data = '''{"client_name": "al seer", "drilldown_type": "high_tenure_customers", "r_score": "4", "f_score": "1"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
    response = requests.post('http://localhost:8002/api/v1/get_drilled_down_data', data=data, headers=header)
#     response = requests.post('http://209.97.130.29:8002/api/v1/get_drilled_down_products_data', data=data, headers=header)
#     print len(response.json()['results'])
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 323
# 1.15457296371
# ...

# %%
# Test Customer Profile
    
data = '''{"client_name": "al seer", "customer_id": "17557", "site_use_id": "2100"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
#     response = requests.post('http://localhost:8000/api/v1/get_customer_profile', data=data, headers=header)
    response = requests.post('http://209.97.130.29:8002/api/v1/get_customer_profile', data=data, headers=header)
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 10.679913044
# ...

# %%
# Test Product Profile
    
data = '''{"client_name": "al seer", "product_id": "18145"}'''

try:
    header={
       'content-type': 'application/json',
       'Authorization': 'Basic %s' % base64.b64encode('trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
    }
    
    start = timeit.default_timer()
#     response = requests.post('http://localhost:8000/api/v1/get_product_profile', data=data, headers=header)
    response = requests.post('http://209.97.130.29:8002/api/v1/get_product_profile', data=data, headers=header)
    print timeit.default_timer() - start
#     response = urlopen(request)
    auth_code = response.json()
    print auth_code
#     print response
    
except Exception as e:
    print str(e)
# Out:
# 6.38685703278
# ...

# %%
base64.b64encode('trainer_admin')
# Out:
# 'dHJhaW5lcl9hZG1pbg=='

# %%
base64.b64encode('4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\n?a:7!8[Df(k>6zK7v-G1')
# Out:
# 'NCRtL0ZyJjRBfWYtbldhS3VKPVdbcVEodl9hfjdhM1trMXNTM3g1YldiCj9hOjchOFtEZihrPjZ6Szd2LUcx'

# %%
base64.b64decode('dHJhaW5lcl9hZG1pbjo0JG0vRnImNEF9Zi1uV2FLdUo9V1txUSh2X2F+N2EzW2sxc1MzeDViV2Jcbj9hOjchOFtEZihrPjZ6Szd2LUcx')
# Out:
# 'trainer_admin:4$m/Fr&4A}f-nWaKuJ=W[qQ(v_a~7a3[k1sS3x5bWb\\n?a:7!8[Df(k>6zK7v-G1'

# %%
import json
import timeit
import requests

# %%
# Segmentation-Service /token
# grant_type=&username=envisageinsights&password=EIsegmentation%402020%234&scope=&client_id=&client_secret=

auth_data = {"username": "envisageinsights", "password": "EIsegmentation@2020#4"}

try:
    response = requests.post('http://127.0.0.1:8000/token', data=auth_data)
    auth_token = response.json()
    print(auth_token)
    
except Exception as e:
    print(str(e))
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlbnZpc2FnZWluc2lnaHRzIiwiZXhwIjoxNjA2MjY0Mzc1fQ.RIlIffBU-1p93EZKnRLxtb0L7M2OmyarHM0DUn4bvLk', 'token_type': 'bearer'}

# %%
#Segmentation-service /rfm_segmentation_with_parameters
header={
   'content-type': 'application/json',
   'Authorization': 'Bearer '+auth_token['access_token']
}

data = {
  "n_segments": 0,
  "data_period": 3,
  "segment_separators": [],
  "geography": {
    "country": [],
    "state": [],
    "city": []
  }
}

try:
    start = timeit.default_timer()
    response = requests.post('http://127.0.0.1:8000/rfm/rfm_segmentation_with_parameters', data=json.dumps(data), headers=header)
    print(response)
    category = response.json()
    print(category, timeit.default_timer() - start)
    
except Exception as e:
    print(str(e))
# Out:
# <Response [200]>
# True 0.43306338600086747
